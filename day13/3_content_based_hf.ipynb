# %%
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
import pandas as pd
import numpy as np
import torch
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoTokenizer, AutoModel

# %%
# tokenizer =

# %% [markdown]
# using berts transformer. //
# all-MiniLM-L6-v2

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

sentences = [
    "The weather is lovely today.",
    "Today class will be over at 3:30",
    "He drove to the stadium",
    "Tomorrow there won't be any class.",
    "She drove to the gym"
]

embeddings = model.encode(sentences)

similarities = model.similarity(embeddings, embeddings)
print(similarities.shape)
# [4, 4]
# Out:
# torch.Size([5, 5])

# %%
print(similarities)
# Out:
# tensor([[1.0000, 0.2484, 0.1058, 0.0967, 0.0630],
#         [0.2484, 1.0000, 0.0725, 0.6234, 0.1193],
#         [0.1058, 0.0725, 1.0000, 0.0446, 0.4892],
#         [0.0967, 0.6234, 0.0446, 1.0000, 0.1157],
#         [0.0630, 0.1193, 0.4892, 0.1157, 1.0000]])

# %% [markdown]
# 1. load the netflix movie data set, titles.csv
# 2. we are going to form content based filtering based on movie description
# 3. check if all description of indian movies are not null
# 4. prepare embedding for each and every description
# 5. now input a query and do model.encode, search each and every embedding and see the similarity score and tabulate the score and sort them.

# %%
movies = pd.read_csv('titles.csv')
movies[movies['production_countries'] == "['IN']"]
# Out:
#              id                               title   type  \
# 19      tm94651                             Dostana  MOVIE
# 25     tm356209                           Singapore  MOVIE
# 29     tm336403                         Khoon Khoon  MOVIE
# 30     tm107372                          Manoranjan  MOVIE
# 31     tm358653                               Ujala  MOVIE
# ...         ...                                 ...    ...
# 5788   tm987730                           Tribhanga  MOVIE
# 5795   tm988613                Madam Chief Minister  MOVIE
# 5819   ts287729  Alma Matters: Inside the IIT Dream   SHOW
# 5821  tm1110241                              Kaaval  MOVIE
# 5831   ts273317                       Pitta Kathalu   SHOW
#
#                                             description  release_year  \
# 19    Two close friends decide to enter law enforcem...          1980
# 25    When his employee disappears in Singapore, Shy...          1960
# ...

# %%
movies['production_countries']
# Out:
# 0             ['US']
# 1             ['US']
# 2             ['US']
# 3             ['GB']
# 4       ['GB', 'US']
#             ...
# 5845          ['NG']
# 5846              []
# 5847          ['CO']
# 5848          ['US']
# 5849              []
# Name: production_countries, Length: 5850, dtype: object
