# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd

np.random.seed(4)
a = np.random.randint(0, 100, (100,3))
a[:, 1:2] *= 9

# Convert only the third column to float
third_col = a[:, 2].astype(float) * 0.1
df = pd.DataFrame({
    'X1': a[:, 0],
    'X2': a[:, 1], 
    'X3': third_col
})
print(df)
# Out:
#     X1   X2   X3
# 0   46  495  6.9
# 1    1  783  7.2
# 2   50   81  5.8
# 3   94  495  5.5
# 4   57  324  5.0
# ..  ..  ...  ...
# 95  16   81  8.7
# 96  86  351  7.9
# 97  27  513  5.4
# 98  99  522  9.0
# 99  71   18  0.7
#
# [100 rows x 3 columns]

# %% [markdown]
# WE HAVE ALL THE COLS IN DIFFERENT KIND OF FORMAT  LIKE WHATEVER BHAI SMJH JAA KHUD
# SO we find Z-SCORE to make it properl comparable.
#
# that is (x1 - mean(x1)) / std(x1) . here x1 is column name

# %% [markdown]
# MANUALLY? NO NO NO
# WE WILL USE STANDARD SCALER

# %%
sc = StandardScaler().set_output(transform='pandas')
sc.fit(df)
dff = sc.transform(df)

# %%
df.mean()
# Out:
# X1     51.450
# X2    407.790
# X3      5.017
# dtype: float64

# %%
df.std()
# Out:
# X1     29.369941
# X2    240.642419
# X3      2.612675
# dtype: float64

# %%
dff
# Out:
#           X1        X2        X3
# 0  -0.186499  0.364231  0.724348
# 1  -1.726396  1.567056  0.839751
# 2  -0.049619 -1.364831  0.301203
# 3   1.456059  0.364231  0.185799
# 4   0.189921 -0.349947 -0.006540
# ..       ...       ...       ...
# 95 -1.213097 -1.364831  1.416768
# 96  1.182299 -0.237182  1.109026
# 97 -0.836678  0.439407  0.147332
# 98  1.627158  0.476996  1.532171
# 99  0.669000 -1.627949 -1.660654
#
# [100 rows x 3 columns]

# %%
dff.mean()
# Out:
# X1   -1.143530e-16
# X2   -8.215650e-17
# X3    3.286260e-16
# dtype: float64

# %%
dff.std()
# Out:
# X1    1.005038
# X2    1.005038
# X3    1.005038
# dtype: float64

# %%
mm = MinMaxScaler().set_output(transform='pandas')
mm.fit(df)
# Out:
# MinMaxScaler()

# %%
dfff = mm.transform(df)
dfff
# Out:
#           X1        X2        X3
# 0   0.464646  0.561224  0.694737
# 1   0.010101  0.887755  0.726316
# 2   0.505051  0.091837  0.578947
# 3   0.949495  0.561224  0.547368
# 4   0.575758  0.367347  0.494737
# ..       ...       ...       ...
# 95  0.161616  0.091837  0.884211
# 96  0.868687  0.397959  0.800000
# 97  0.272727  0.581633  0.536842
# 98  1.000000  0.591837  0.915789
# 99  0.717172  0.020408  0.042105
#
# [100 rows x 3 columns]
