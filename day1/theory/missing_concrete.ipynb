# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
from sklearn.impute import SimpleImputer

# %%
training_cement = pd.read_csv('../cases/Concrete_Strength/Concrete_Data.csv')
X = training_cement.drop('Strength', axis=1)
y = training_cement['Strength']
testing_cement = pd.read_csv('../cases/Concrete_Strength/testConcreteMissing.csv')
training_cement
# Out:
#       Cement  Blast    Fly  Water  Superplasticizer  Coarse   Fine  Age  \
# 0      540.0    0.0    0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0    0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5    0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5    0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4    0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...    ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0   90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0  115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4  108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7    0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5   78.3  200.6               8.6   864.5  761.5   28
#
#       Strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# 4        44.30
# ...

# %%
imputer = SimpleImputer(strategy='mean').set_output(transform='pandas')
imputer.fit(X)
testing_cement = imputer.transform(testing_cement)

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(testing_cement)
# Out:
# array([68.73718457, 44.92754382, 29.09844489, 27.43221577, 56.55844543,
#        18.83513067, 50.30685651, 81.86351485, 24.60173472, 42.79473839,
#        43.44332935, 66.11413244, 50.80518635, 15.38709673])
